# %% [markdown]
# <font size='5'><h1 ><center> **Plants Identification by Deep Learning**</center></h1></font>

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#acces">Introduction</a></li>
#         <li><a href="#acces">Acces files in drive</a></li>
#         <li><a href="#Preprocess_data">Data preprocessing and exploring </a></li>
#         <li><a href="#modeling">Modeling</a></li>
#         <li><a href="#mevaluation">Evaluation</a></li>
#         <li><a href="#prediction">Prediction</a></li>
#     </ol>
# </div>
# <br>

# %% [markdown]
# ### **Introduction**
#
# <font size='3'>"Automated species identification was presented 15 years ago as a challenging but very promising solution for the development of new research activities in Taxonomy, Biology or Ecology. However, identifying a plant for a botanist means associating a scientific name to an individual plant. More precisely, that means assigning that individual plant to a group, called a taxon. Such taxon had a name selected according to a set of rules. The delimitation of taxa and the scientific names applying to them are the result of a process called taxonomy (or systematics)".
#
# Our project aims to create a solution that can identify a plant in an automated way. so I’m going to implement full CNN from scratch in Keras with a TensorFlow backend. This implementation will be performed on a dataset of five different kind flower. These flowers are daisy, dandelion, rose, sunflower and tulip.<font>

# %% [markdown]
# # Memory Information

# %%
import psutil
def get_size(bytes, suffix="B"):
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor
print("="*40, "Memory Information", "="*40)
svmem = psutil.virtual_memory()
print(f"Total: {get_size(svmem.total)}") ; print(f"Available: {get_size(svmem.available)}")
print(f"Used: {get_size(svmem.used)}") ; print(f"Percentage: {svmem.percent}%")
# Out:
# ======================================== Memory Information ========================================
# Total: 25.51GB
# Available: 24.60GB
# Used: 588.71MB
# Percentage: 3.6%

# %% [markdown]
# # GPU Information

# %%
! nvidia-smi
# Out:
# Mon Oct  5 21:45:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### **Access files in Drive**
# > We can access files in Drive in a number of ways, including: Mounting our Google Drive in the runtime's virtual machine using an authorization code

# %%
from google.colab import drive 
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# #### Load required libraries

# %%
import numpy as np # linear algebra
import pandas as pd  # data processing
import os #  to interact with files using there paths
from sklearn.datasets import load_files

# %% [markdown]
# ### Loading the Data

# %%
#The path of our data on drive
data_dir =  r'/gdrive/My Drive/flowers'
 
#Loading our Data
data = load_files(data_dir)

# %% [markdown]
# ### **Data Preprocessing and exploring**

# %%
folders=os.listdir("/gdrive/My Drive/flowers")
print(folders)
# Out:
# ['tulip', 'dandelion', 'daisy', 'sunflower', 'rose']

# %% [markdown]
# #### We have one folder for each flower classe or type. We are going to load it into two numpy arrays as follows :
#
# - X - filenames (Training data)
# - y - flower names(Target labels)

# %%
X = np.array(data['filenames'])
y = np.array(data['target'])
labels = np.array(data['target_names'])
 
# How the arrays look like?
print('Data files - ',X)
print('Target labels - ',y)
# Out:
# Data files -  ['/gdrive/My Drive/flowers/tulip/8585102913_d80d3e2ff7_n.jpg'
#  '/gdrive/My Drive/flowers/tulip/13562271714_d534531374.jpg'
#  '/gdrive/My Drive/flowers/rose/3253243865_435c1f2c2b_m.jpg' ...
#  '/gdrive/My Drive/flowers/dandelion/7153497513_076486e26b_n.jpg'
#  '/gdrive/My Drive/flowers/rose/9614492283_66020fb4eb_n.jpg'
#  '/gdrive/My Drive/flowers/sunflower/15493195788_60530f2398_m.jpg']
# Target labels -  [4 4 2 ... 1 2 3]

# %% [markdown]
# #### As you can see, numbers in the **Target labels - [4 4 2 ... 1 2 3]** are corresponding to class label. We need to change them to a vector of 5 elements ( 5 classes )

# %% [markdown]
# ### Remove .pyc or .py files
# > If you explore our data closely, you will see some other files that are not images with the '.pyc' and '.py' extensions, especially in the dandelion class. So, we have to remove them.
#
# > Don't worry, you may not want to do it that way. however, you can simply work with files whose names end with the extension .jpg using the **endswith ('jpg')** function properly.

# %%
# Remove .pyc or .py files
pyc_file_pos = (np.where(file==X) for file in X if file.endswith(('.pyc','.py')))
for pos in pyc_file_pos:
    X = np.delete(X,pos)
    y = np.delete(y,pos)
    
print('Number of training files : ', X.shape[0])
print('Number of training targets : ', y.shape[0])
# Out:
# Number of training files :  4328
# Number of training targets :  4328

# %% [markdown]
# ### Load the images
# > We only have the filenames in X. So, it's time to load the images from the filename with an appropriate size which ensures a small number of parameters to minimize runtime as much as possible during the training step and save them to X. Here we are going to use (150, 150) as the image size for the previous reasons.

# %%
from keras.preprocessing.image import img_to_array, load_img

def convert_img_to_arr(file_path_list):
    arr = []
    #size=64,64
    img_width, img_height = 150,150
    for file_path in file_path_list:
        img = load_img(file_path, target_size = (img_width, img_height))
        img = img_to_array(img)
        arr.append(img)
        #arr.append(cv2.resize(img,size))
    return arr
 
X = np.array(convert_img_to_arr(X))
print(X.shape) 
print('First training item : ',X[0])
# Out:
# (4328, 150, 150, 3)
# First training item :  [[[ 29.  29.  29.]
#   [ 29.  29.  29.]
#   [ 30.  30.  32.]
#   ...
#   [  7.   7.   5.]
#   [  7.   7.   5.]
#   [  6.   6.   4.]]
#
#  [[ 29.  29.  29.]
#   [ 29.  29.  29.]
#   [ 30.  30.  32.]
#   ...
#   [  7.   7.   5.]
#   [  7.   7.   5.]
#   [  7.   7.   5.]]
#
#  [[ 29.  29.  29.]
#   [ 29.  29.  29.]
#   [ 30.  30.  32.]
#   ...
#   [  7.   7.   5.]
#   [  7.   7.   5.]
#   [  7.   7.   5.]]
#
#  ...
#
#  [[ 33.  22.  20.]
#   [ 33.  22.  20.]
#   [ 33.  22.  20.]
#   ...
#   [ 86.  93.  86.]
#   [ 96. 107.  93.]
#   [ 23.  37.   4.]]
#
#  [[ 33.  22.  20.]
#   [ 33.  22.  20.]
#   [ 33.  22.  20.]
#   ...
#   [ 25.  37.   1.]
#   [ 29.  44.   3.]
#   [ 38.  55.   0.]]
#
#  [[ 33.  22.  20.]
#   [ 33.  22.  20.]
#   [ 33.  22.  20.]
#   ...
#   [ 38.  50.  14.]
#   [ 34.  48.  13.]
#   [ 38.  53.  10.]]]

# %% [markdown]
# #### **Few Take Aways**
# #### Note that the shape of training data is **(4323, 150, 150, 3)**
# #####
#
# -   **4323** is the **number** of training items or files,
# -   **(150,150)** is the **target size** or image size provided while loading image
# -   **3** refers to the **depth** for colored images ( RGB channels ).

# %% [markdown]
# ### Take a look at some pictures

# %%
#Let's look at first 5 training data.

import matplotlib.pyplot as plt
 
fig = plt.figure(figsize = (16,9))
for i in range(5):
    ax = fig.add_subplot(1,5,i+1,xticks=[],yticks=[])
    ax.imshow((X[i].astype(np.uint8)))
    plt.title(folders[y[i]])

# %% [markdown]
# Spectacular! The flowers are so beautiful :)

# %% [markdown]
# ### Why we need to [rescal](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) our data ?
# > rescale is a value by which we will multiply the data before any other processing. Our original images consist in RGB coefficients in the 0-255, but such values would be too high for our models to process (given a typical learning rate), so we target values between 0 and 1 instead by scaling with a 1/255. factor. So all values in X will lie within 0 to 1 !

# %%
# Let's resize or rescale training data
X = X.astype('float32')/255
 
# Let's confirm the number of classes :) 
no_of_classes = len(np.unique(y))
no_of_classes
# Out:
# 5

# %% [markdown]
# > Great! we will predict the flowers of five classes

# %%
y
# Out:
# array([4, 4, 2, ..., 1, 2, 3])

# %% [markdown]
#  ### Let's converts a class vector (integers) to binary class matrix:
# **Arguments:**
# - **y**	class vector to be converted into a matrix (integers from 0 to no_of_classes).
# - **no_of_classes** total number of classes.
# - **dtype**	The data type expected by the input. Default: 'float32'.
#
# **Returns:**
# - A binary matrix representation of the input. The classes axis is placed last. [for more...](https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/keras/utils/to_categorical)

# %%
from keras.utils import np_utils

# let's converts a class vector (integers) to binary class matrix.
y = np.array(np_utils.to_categorical(y,no_of_classes))
y[0]
# Out:
# array([0., 0., 0., 0., 1.], dtype=float32)

# %% [markdown]
# ### Split the data into train, test and valid subsets
# > Here we are going to split our dataset into **80% train**, **10% validation**, and **10% test**.

# %%
from sklearn.model_selection import train_test_split

# let's splite the data into subsets and explore their shapes !

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
print('The test Data Shape ', X_test.shape[0])
 
X_test, X_valid, y_test, y_valid = train_test_split(X_test,y_test, test_size = 0.5)
print('The training Data Shape ', X_valid.shape[0])
# Out:
# The test Data Shape  866
# The training Data Shape  433

# %%
print('The train Data Shape ', X_train.shape[1:])
# Out:
# The train Data Shape  (150, 150, 3)

# %% [markdown]
# > (150, 150, 3) refers to the shape of the data (images) that will be fed into our CNN

# %% [markdown]
# ### **CNN Implementation**
# > This is an image that shows how our CNN architecture looks like :

# %% [markdown]
# ![CNN AR.png](data:image/png;base64,...)

# %% [markdown]
# ### Import the necessary libraries
# > As you can see here, Keras library allows us to import the different functions for building our CNN architecture (Conv2D, MaxPooling2D, Dense, Flatten Dropout.

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ### CNN Architecture
# I will be using Sequential method as I am creating a sequential model. **Sequential model means that all the layers of the model will be arranged in sequence**, then i will add:
# > * 2 x convolution layer of 32 channel of 3x3 kernal and same padding;
# * 1 x maxpool layer of 2x2 pool size;
# * 1 x droupt with a frequency of rate equal to 0.25;
# * 2 x convolution layer of 64 channel of 3x3 kernal and same padding:
# * 1 x maxpool layer of 2x2 pool size
# * 1 x droupt with a frequency of rate equal to 0.25;
# * 2 x convolution layer of 128 channel of 3x3 kernal and same padding;
# * 1 x maxpool layer of 2x2 pool size;
# * 1 x flatten;
# * 1 x dense layer of 512
# * 1 x dropout set at 0.5
# * 1 x dense layer of 128
# * 1 x Dense Softmax layer of 5 units
#
# => **Dropout** is a technique of regularisation which helps us to prevent _**overfitting**_.
#
# If you noticed, I also add **ReLu** (Rectified Linear Unit) activation to each layers so that all the negative values are not passed to the next layer:)

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', input_shape=X_train.shape[1:], activation='relu', name='Conv2D_1'))
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', name='Conv2D_2'))
model.add(MaxPool2D(pool_size=(2,2), name='Maxpool_1'))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', name='Conv2D_3'))
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', name='Conv2D_4'))
model.add(MaxPool2D(pool_size=(2,2), name='Maxpool_2'))
model.add(Dropout(0.25))
    
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', name='Conv2D_5'))
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', name='Conv2D_6'))
model.add(MaxPool2D(pool_size=(2,2), name='Maxpool_3'))

model.add(Flatten())
model.add(Dense(units=512, activation='relu', name='Dense_1'))
model.add(Dropout(0.5))
model.add(Dense(units=128, activation='relu', name='Dense_2'))
model.add(Dense(units=no_of_classes, activation='softmax', name='Output'))

# %% [markdown]
# ### Model Summary

# %%
# Getting the summary of the model
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv2D_1 (Conv2D)            (None, 150, 150, 32)      896
# _________________________________________________________________
# Conv2D_2 (Conv2D)            (None, 148, 148, 32)      9248
# _________________________________________________________________
# Maxpool_1 (MaxPooling2D)     (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 74, 74, 32)        0
# _________________________________________________________________
# Conv2D_3 (Conv2D)            (None, 74, 74, 64)        18496
# _________________________________________________________________
# Conv2D_4 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# Maxpool_2 (MaxPooling2D)     (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 36, 36, 64)        0
# _________________________________________________________________
# Conv2D_5 (Conv2D)            (None, 36, 36, 128)       73856
# _________________________________________________________________
# Conv2D_6 (Conv2D)            (None, 34, 34, 128)       147584
# _________________________________________________________________
# Maxpool_3 (MaxPooling2D)     (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# Dense_1 (Dense)              (None, 512)               18940416
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# Dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# Output (Dense)               (None, 5)                 645
# =================================================================
# Total params: 19,293,733
# Trainable params: 19,293,733
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model
# > I will be using the **RMSprop** optimizer to Maintain a moving (updated) average of the square of the gradients during training, here, in this case, it is fixed at 0.001. If our training bounces a lot off epochs, we need to reduce the learning rate to maintain a moving average.

# %%
from keras.optimizers import RMSprop

optimizer = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Fitting the model
# For callbacks, I employed:
#
#
# >* **ModelCheckpoint :** Callback to save the model or model weights at certain frequencies (in this case, the model will be saved That only if the validation accuracy of the model at the present time is greater than that at the last time)
# * **ReduceLRonPlateau :** Reduce learning rate when a performance metric has stopped improving (in this case, I have set the patience at 3, which means that the model will reduce the learning rate if it does not see any increase in the validation precision in 3 epochs)
#
#    I am using **model.fit_generator** because I am using **ImageDataGenerator** to pass data to the model. I will pass the train and valid data to **fit_generator**. In **fit_generator**, **steps_per_epoch** will set the **batch_size** to pass training data to the model and **validation_steps** will do the same for validation data. These settings could be changed according to each system specifications.

# %%
import time
from keras.callbacks import ModelCheckpoint, EarlyStopping
 
# Time to train our model !
epochs = 100
batch_size=32
 
train_datagen = ImageDataGenerator(
        rotation_range=10,  
        zoom_range = 0.1, 
        width_shift_range=0.1,
        height_shift_range=0.1,  
        horizontal_flip=True)
 
test_datagen = ImageDataGenerator()
 
train_generator = train_datagen.flow(
    X_train,y_train,
    batch_size=batch_size)
 
validation_generator = test_datagen.flow(
    X_valid,y_valid,
    batch_size=batch_size)
 
checkpointer = ModelCheckpoint(filepath = "/gdrive/My Drive/PId_Best.h5", save_best_only = True, verbose = 1)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose = 1, factor = 0.5, minlr = 0.00001)
 

start = time.time()
 
# let's get started !
 
history=model.fit_generator(train_generator,
                            epochs=epochs,
                            validation_data = validation_generator,
                            verbose=1,
                            steps_per_epoch=len(X_train) // batch_size,
                            #validation_steps=len(X_valid) //batch_size,
                            callbacks=[checkpointer, learning_rate_reduction])
 
end = time.time()
 
duration = end - start
print ('\n This Model took %0.2f seconds (%0.1f minutes) to train for %d epochs'%(duration, duration/60, epochs) )
# Out:
# Epoch 1/100
# 108/108 [==============================] - ETA: 0s - loss: 1.9027 - accuracy: 0.3137
# Epoch 00001: val_loss improved from inf to 1.41466, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 167ms/step - loss: 1.9027 - accuracy: 0.3137 - val_loss: 1.4147 - val_accuracy: 0.3741
# Epoch 2/100
# 108/108 [==============================] - ETA: 0s - loss: 1.3466 - accuracy: 0.4265
# Epoch 00002: val_loss improved from 1.41466 to 1.32491, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 173ms/step - loss: 1.3466 - accuracy: 0.4265 - val_loss: 1.3249 - val_accuracy: 0.3695
# Epoch 3/100
# 108/108 [==============================] - ETA: 0s - loss: 1.2209 - accuracy: 0.4948
# Epoch 00003: val_loss improved from 1.32491 to 1.20880, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 174ms/step - loss: 1.2209 - accuracy: 0.4948 - val_loss: 1.2088 - val_accuracy: 0.4619
# Epoch 4/100
# 108/108 [==============================] - ETA: 0s - loss: 1.1433 - accuracy: 0.5571
# Epoch 00004: val_loss improved from 1.20880 to 1.03005, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 176ms/step - loss: 1.1433 - accuracy: 0.5571 - val_loss: 1.0300 - val_accuracy: 0.6074
# Epoch 5/100
# 108/108 [==============================] - ETA: 0s - loss: 1.0610 - accuracy: 0.5851
# Epoch 00005: val_loss improved from 1.03005 to 0.95982, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 175ms/step - loss: 1.0610 - accuracy: 0.5851 - val_loss: 0.9598 - val_accuracy: 0.6420
# Epoch 6/100
# 108/108 [==============================] - ETA: 0s - loss: 0.9942 - accuracy: 0.6204
# Epoch 00006: val_loss did not improve from 0.95982
# 108/108 [==============================] - 18s 165ms/step - loss: 0.9942 - accuracy: 0.6204 - val_loss: 1.0827 - val_accuracy: 0.5912
# Epoch 7/100
# 108/108 [==============================] - ETA: 0s - loss: 0.9370 - accuracy: 0.6402
# Epoch 00007: val_loss improved from 0.95982 to 0.83204, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 169ms/step - loss: 0.9370 - accuracy: 0.6402 - val_loss: 0.8320 - val_accuracy: 0.7021
# Epoch 8/100
# 108/108 [==============================] - ETA: 0s - loss: 0.9032 - accuracy: 0.6603
# Epoch 00008: val_loss did not improve from 0.83204
# 108/108 [==============================] - 18s 165ms/step - loss: 0.9032 - accuracy: 0.6603 - val_loss: 0.9627 - val_accuracy: 0.6236
# Epoch 9/100
# 108/108 [==============================] - ETA: 0s - loss: 0.8709 - accuracy: 0.6738
# Epoch 00009: val_loss improved from 0.83204 to 0.74751, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 171ms/step - loss: 0.8709 - accuracy: 0.6738 - val_loss: 0.7475 - val_accuracy: 0.7206
# Epoch 10/100
# 108/108 [==============================] - ETA: 0s - loss: 0.8428 - accuracy: 0.6843
# Epoch 00010: val_loss did not improve from 0.74751
# 108/108 [==============================] - 18s 164ms/step - loss: 0.8428 - accuracy: 0.6843 - val_loss: 0.7606 - val_accuracy: 0.7460
# Epoch 11/100
# 108/108 [==============================] - ETA: 0s - loss: 0.8217 - accuracy: 0.7025
# Epoch 00011: val_loss improved from 0.74751 to 0.70229, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 176ms/step - loss: 0.8217 - accuracy: 0.7025 - val_loss: 0.7023 - val_accuracy: 0.7575
# Epoch 12/100
# 108/108 [==============================] - ETA: 0s - loss: 0.8071 - accuracy: 0.7012
# Epoch 00012: val_loss did not improve from 0.70229
# 108/108 [==============================] - 18s 164ms/step - loss: 0.8071 - accuracy: 0.7012 - val_loss: 0.7274 - val_accuracy: 0.7598
# Epoch 13/100
# 108/108 [==============================] - ETA: 0s - loss: 0.8382 - accuracy: 0.7111
# Epoch 00013: val_loss did not improve from 0.70229
# 108/108 [==============================] - 17s 162ms/step - loss: 0.8382 - accuracy: 0.7111 - val_loss: 0.7232 - val_accuracy: 0.7113
# Epoch 14/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7677 - accuracy: 0.7187
# Epoch 00014: val_loss did not improve from 0.70229
# 108/108 [==============================] - 17s 162ms/step - loss: 0.7677 - accuracy: 0.7187 - val_loss: 0.7955 - val_accuracy: 0.7390
# Epoch 15/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.7195
# Epoch 00015: val_loss did not improve from 0.70229
# 108/108 [==============================] - 17s 162ms/step - loss: 0.7441 - accuracy: 0.7195 - val_loss: 0.7592 - val_accuracy: 0.7714
# Epoch 16/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7446 - accuracy: 0.7385
# Epoch 00016: val_loss did not improve from 0.70229
# 108/108 [==============================] - 17s 162ms/step - loss: 0.7446 - accuracy: 0.7385 - val_loss: 0.7612 - val_accuracy: 0.7275
# Epoch 17/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7509 - accuracy: 0.7262
# Epoch 00017: val_loss improved from 0.70229 to 0.68303, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 171ms/step - loss: 0.7509 - accuracy: 0.7262 - val_loss: 0.6830 - val_accuracy: 0.7644
# Epoch 18/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7140 - accuracy: 0.7303
# Epoch 00018: val_loss improved from 0.68303 to 0.67082, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 173ms/step - loss: 0.7140 - accuracy: 0.7303 - val_loss: 0.6708 - val_accuracy: 0.7852
# Epoch 19/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7130 - accuracy: 0.7350
# Epoch 00019: val_loss did not improve from 0.67082
# 108/108 [==============================] - 18s 165ms/step - loss: 0.7130 - accuracy: 0.7350 - val_loss: 0.7433 - val_accuracy: 0.7621
# Epoch 20/100
# 108/108 [==============================] - ETA: 0s - loss: 0.7097 - accuracy: 0.7501
# Epoch 00020: val_loss did not improve from 0.67082
# 108/108 [==============================] - 18s 163ms/step - loss: 0.7097 - accuracy: 0.7501 - val_loss: 0.6809 - val_accuracy: 0.7875
# Epoch 21/100
# 108/108 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.7507
# Epoch 00021: val_loss did not improve from 0.67082
# 108/108 [==============================] - 17s 162ms/step - loss: 0.6799 - accuracy: 0.7507 - val_loss: 0.7291 - val_accuracy: 0.7390
# Epoch 22/100
# 108/108 [==============================] - ETA: 0s - loss: 0.6864 - accuracy: 0.7528
# Epoch 00022: val_loss did not improve from 0.67082
# 108/108 [==============================] - 17s 161ms/step - loss: 0.6864 - accuracy: 0.7528 - val_loss: 0.7183 - val_accuracy: 0.7806
# Epoch 23/100
# 108/108 [==============================] - ETA: 0s - loss: 0.6820 - accuracy: 0.7571
# Epoch 00023: val_loss did not improve from 0.67082
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 108/108 [==============================] - 17s 161ms/step - loss: 0.6820 - accuracy: 0.7571 - val_loss: 0.7074 - val_accuracy: 0.7644
# Epoch 24/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5514 - accuracy: 0.7971
# Epoch 00024: val_loss improved from 0.67082 to 0.66631, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 170ms/step - loss: 0.5514 - accuracy: 0.7971 - val_loss: 0.6663 - val_accuracy: 0.7667
# Epoch 25/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5411 - accuracy: 0.7948
# Epoch 00025: val_loss improved from 0.66631 to 0.63306, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 172ms/step - loss: 0.5411 - accuracy: 0.7948 - val_loss: 0.6331 - val_accuracy: 0.8014
# Epoch 26/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.7968
# Epoch 00026: val_loss improved from 0.63306 to 0.62107, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 173ms/step - loss: 0.5218 - accuracy: 0.7968 - val_loss: 0.6211 - val_accuracy: 0.8176
# Epoch 27/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.8099
# Epoch 00027: val_loss did not improve from 0.62107
# 108/108 [==============================] - 18s 165ms/step - loss: 0.5131 - accuracy: 0.8099 - val_loss: 0.6929 - val_accuracy: 0.8037
# Epoch 28/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5095 - accuracy: 0.8149
# Epoch 00028: val_loss improved from 0.62107 to 0.60701, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 19s 174ms/step - loss: 0.5095 - accuracy: 0.8149 - val_loss: 0.6070 - val_accuracy: 0.8291
# Epoch 29/100
# 108/108 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.8213
# Epoch 00029: val_loss did not improve from 0.60701
# 108/108 [==============================] - 18s 164ms/step - loss: 0.5153 - accuracy: 0.8213 - val_loss: 0.6876 - val_accuracy: 0.8083
# Epoch 30/100
# 108/108 [==============================] - ETA: 0s - loss: 0.4823 - accuracy: 0.8245
# Epoch 00030: val_loss did not improve from 0.60701
# 108/108 [==============================] - 17s 162ms/step - loss: 0.4823 - accuracy: 0.8245 - val_loss: 0.6244 - val_accuracy: 0.8199
# Epoch 31/100
# 108/108 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.8102
# Epoch 00031: val_loss did not improve from 0.60701
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 108/108 [==============================] - 18s 162ms/step - loss: 0.4956 - accuracy: 0.8102 - val_loss: 0.6582 - val_accuracy: 0.8106
# Epoch 32/100
# 108/108 [==============================] - ETA: 0s - loss: 0.4235 - accuracy: 0.8472
# Epoch 00032: val_loss did not improve from 0.60701
# 108/108 [==============================] - 18s 163ms/step - loss: 0.4235 - accuracy: 0.8472 - val_loss: 0.6861 - val_accuracy: 0.8152
# Epoch 33/100
# 108/108 [==============================] - ETA: 0s - loss: 0.4031 - accuracy: 0.8493
# Epoch 00033: val_loss improved from 0.60701 to 0.60700, saving model to /gdrive/My Drive/PId_Best.h5
# 108/108 [==============================] - 18s 171ms/step - loss: 0.4031 - accuracy: 0.8493 - val_loss: 0.6070 - val_accuracy: 0.8152
# Epoch 34/100
# 108/108 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.8525
# Epoch 00034: val_loss did not improve from 0.60700
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 108/108 [==============================] - 18s 165ms/step - loss: 0.4065 - accuracy: 0.8525 - val_loss: 0.7288 - val_accuracy: 0.8176
# Epoch 35/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8641
# Epoch 00035: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.3740 - accuracy: 0.8641 - val_loss: 0.7213 - val_accuracy: 0.8245
# Epoch 36/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8650
# Epoch 00036: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.3596 - accuracy: 0.8650 - val_loss: 0.6925 - val_accuracy: 0.8083
# Epoch 37/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3587 - accuracy: 0.8697
# Epoch 00037: val_loss did not improve from 0.60700
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 108/108 [==============================] - 18s 164ms/step - loss: 0.3587 - accuracy: 0.8697 - val_loss: 0.6125 - val_accuracy: 0.8222
# Epoch 38/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.8723
# Epoch 00038: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3394 - accuracy: 0.8723 - val_loss: 0.6364 - val_accuracy: 0.8268
# Epoch 39/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3485 - accuracy: 0.8743
# Epoch 00039: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3485 - accuracy: 0.8743 - val_loss: 0.6601 - val_accuracy: 0.8245
# Epoch 40/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8805
# Epoch 00040: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.3305 - accuracy: 0.8805 - val_loss: 0.6451 - val_accuracy: 0.8314
# Epoch 41/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8834
# Epoch 00041: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3295 - accuracy: 0.8834 - val_loss: 0.6769 - val_accuracy: 0.8222
# Epoch 42/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.8819
# Epoch 00042: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3140 - accuracy: 0.8819 - val_loss: 0.6472 - val_accuracy: 0.8199
# Epoch 43/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.8831
# Epoch 00043: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.3135 - accuracy: 0.8831 - val_loss: 0.6619 - val_accuracy: 0.8360
# Epoch 44/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8755
# Epoch 00044: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3236 - accuracy: 0.8755 - val_loss: 0.7077 - val_accuracy: 0.8222
# Epoch 45/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8843
# Epoch 00045: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.3232 - accuracy: 0.8843 - val_loss: 0.6807 - val_accuracy: 0.8199
# Epoch 46/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.8860
# Epoch 00046: val_loss did not improve from 0.60700
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 108/108 [==============================] - 18s 164ms/step - loss: 0.3120 - accuracy: 0.8860 - val_loss: 0.6401 - val_accuracy: 0.8245
# Epoch 47/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3042 - accuracy: 0.8857
# Epoch 00047: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.3042 - accuracy: 0.8857 - val_loss: 0.6860 - val_accuracy: 0.8152
# Epoch 48/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8875
# Epoch 00048: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 161ms/step - loss: 0.2988 - accuracy: 0.8875 - val_loss: 0.6857 - val_accuracy: 0.8176
# Epoch 49/100
# 108/108 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.8913
# Epoch 00049: val_loss did not improve from 0.60700
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 108/108 [==============================] - 17s 161ms/step - loss: 0.3016 - accuracy: 0.8913 - val_loss: 0.6986 - val_accuracy: 0.8291
# Epoch 50/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8872
# Epoch 00050: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2987 - accuracy: 0.8872 - val_loss: 0.7044 - val_accuracy: 0.8245
# Epoch 51/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.8913
# Epoch 00051: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2950 - accuracy: 0.8913 - val_loss: 0.7112 - val_accuracy: 0.8199
# Epoch 52/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.8921
# Epoch 00052: val_loss did not improve from 0.60700
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2891 - accuracy: 0.8921 - val_loss: 0.6984 - val_accuracy: 0.8245
# Epoch 53/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8927
# Epoch 00053: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.2886 - accuracy: 0.8927 - val_loss: 0.6956 - val_accuracy: 0.8268
# Epoch 54/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8942
# Epoch 00054: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2883 - accuracy: 0.8942 - val_loss: 0.7042 - val_accuracy: 0.8245
# Epoch 55/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8985
# Epoch 00055: val_loss did not improve from 0.60700
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 108/108 [==============================] - 18s 162ms/step - loss: 0.2803 - accuracy: 0.8985 - val_loss: 0.6877 - val_accuracy: 0.8199
# Epoch 56/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8939
# Epoch 00056: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2869 - accuracy: 0.8939 - val_loss: 0.6890 - val_accuracy: 0.8245
# Epoch 57/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8980
# Epoch 00057: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 160ms/step - loss: 0.2856 - accuracy: 0.8980 - val_loss: 0.6916 - val_accuracy: 0.8222
# Epoch 58/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8971
# Epoch 00058: val_loss did not improve from 0.60700
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 108/108 [==============================] - 17s 161ms/step - loss: 0.2930 - accuracy: 0.8971 - val_loss: 0.6942 - val_accuracy: 0.8199
# Epoch 59/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8950
# Epoch 00059: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2829 - accuracy: 0.8950 - val_loss: 0.6887 - val_accuracy: 0.8222
# Epoch 60/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8945
# Epoch 00060: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 161ms/step - loss: 0.2868 - accuracy: 0.8945 - val_loss: 0.6964 - val_accuracy: 0.8199
# Epoch 61/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8918
# Epoch 00061: val_loss did not improve from 0.60700
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2910 - accuracy: 0.8918 - val_loss: 0.6968 - val_accuracy: 0.8199
# Epoch 62/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2851 - accuracy: 0.8927
# Epoch 00062: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 161ms/step - loss: 0.2851 - accuracy: 0.8927 - val_loss: 0.6962 - val_accuracy: 0.8199
# Epoch 63/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9026
# Epoch 00063: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.2738 - accuracy: 0.9026 - val_loss: 0.6977 - val_accuracy: 0.8199
# Epoch 64/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8901
# Epoch 00064: val_loss did not improve from 0.60700
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 108/108 [==============================] - 18s 162ms/step - loss: 0.2873 - accuracy: 0.8901 - val_loss: 0.6976 - val_accuracy: 0.8199
# Epoch 65/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8901
# Epoch 00065: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2861 - accuracy: 0.8901 - val_loss: 0.6991 - val_accuracy: 0.8199
# Epoch 66/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.8936
# Epoch 00066: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.2860 - accuracy: 0.8936 - val_loss: 0.6993 - val_accuracy: 0.8199
# Epoch 67/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.8956
# Epoch 00067: val_loss did not improve from 0.60700
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2870 - accuracy: 0.8956 - val_loss: 0.6992 - val_accuracy: 0.8199
# Epoch 68/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8918
# Epoch 00068: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2856 - accuracy: 0.8918 - val_loss: 0.6997 - val_accuracy: 0.8199
# Epoch 69/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2855 - accuracy: 0.8907
# Epoch 00069: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2855 - accuracy: 0.8907 - val_loss: 0.6996 - val_accuracy: 0.8199
# Epoch 70/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.8854
# Epoch 00070: val_loss did not improve from 0.60700
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 108/108 [==============================] - 17s 161ms/step - loss: 0.2964 - accuracy: 0.8854 - val_loss: 0.6993 - val_accuracy: 0.8199
# Epoch 71/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.8889
# Epoch 00071: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.2842 - accuracy: 0.8889 - val_loss: 0.6993 - val_accuracy: 0.8199
# Epoch 72/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.8918
# Epoch 00072: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2882 - accuracy: 0.8918 - val_loss: 0.6996 - val_accuracy: 0.8199
# Epoch 73/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8930
# Epoch 00073: val_loss did not improve from 0.60700
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2854 - accuracy: 0.8930 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 74/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.8956
# Epoch 00074: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2814 - accuracy: 0.8956 - val_loss: 0.6997 - val_accuracy: 0.8199
# Epoch 75/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8936
# Epoch 00075: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2866 - accuracy: 0.8936 - val_loss: 0.6996 - val_accuracy: 0.8199
# Epoch 76/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8939
# Epoch 00076: val_loss did not improve from 0.60700
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2782 - accuracy: 0.8939 - val_loss: 0.6996 - val_accuracy: 0.8199
# Epoch 77/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8939
# Epoch 00077: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2887 - accuracy: 0.8939 - val_loss: 0.6997 - val_accuracy: 0.8199
# Epoch 78/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8918
# Epoch 00078: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.2854 - accuracy: 0.8918 - val_loss: 0.6997 - val_accuracy: 0.8199
# Epoch 79/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.9017
# Epoch 00079: val_loss did not improve from 0.60700
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2862 - accuracy: 0.9017 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 80/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8945
# Epoch 00080: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2857 - accuracy: 0.8945 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 81/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8880
# Epoch 00081: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2876 - accuracy: 0.8880 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 82/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8983
# Epoch 00082: val_loss did not improve from 0.60700
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2749 - accuracy: 0.8983 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 83/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.8968
# Epoch 00083: val_loss did not improve from 0.60700
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2841 - accuracy: 0.8968 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 84/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.8930
# Epoch 00084: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 162ms/step - loss: 0.2781 - accuracy: 0.8930 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 85/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8901
# Epoch 00085: val_loss did not improve from 0.60700
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 108/108 [==============================] - 17s 162ms/step - loss: 0.2996 - accuracy: 0.8901 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 86/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8941
# Epoch 00086: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 166ms/step - loss: 0.2988 - accuracy: 0.8941 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 87/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.8878
# Epoch 00087: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.2929 - accuracy: 0.8878 - val_loss: 0.6999 - val_accuracy: 0.8199
# Epoch 88/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2802 - accuracy: 0.8962
# Epoch 00088: val_loss did not improve from 0.60700
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 108/108 [==============================] - 18s 163ms/step - loss: 0.2802 - accuracy: 0.8962 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 89/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8913
# Epoch 00089: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 164ms/step - loss: 0.2840 - accuracy: 0.8913 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 90/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8939
# Epoch 00090: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 166ms/step - loss: 0.2862 - accuracy: 0.8939 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 91/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.8953
# Epoch 00091: val_loss did not improve from 0.60700
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 108/108 [==============================] - 18s 168ms/step - loss: 0.2890 - accuracy: 0.8953 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 92/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8942
# Epoch 00092: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 168ms/step - loss: 0.2847 - accuracy: 0.8942 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 93/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.8980
# Epoch 00093: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 167ms/step - loss: 0.2726 - accuracy: 0.8980 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 94/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.8945
# Epoch 00094: val_loss did not improve from 0.60700
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 108/108 [==============================] - 18s 168ms/step - loss: 0.2780 - accuracy: 0.8945 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 95/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8936
# Epoch 00095: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 167ms/step - loss: 0.2817 - accuracy: 0.8936 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 96/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.8918
# Epoch 00096: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 167ms/step - loss: 0.2958 - accuracy: 0.8918 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 97/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8913
# Epoch 00097: val_loss did not improve from 0.60700
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 108/108 [==============================] - 18s 168ms/step - loss: 0.2909 - accuracy: 0.8913 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 98/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9000
# Epoch 00098: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 169ms/step - loss: 0.2749 - accuracy: 0.9000 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 99/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8930
# Epoch 00099: val_loss did not improve from 0.60700
# 108/108 [==============================] - 18s 167ms/step - loss: 0.2798 - accuracy: 0.8930 - val_loss: 0.6998 - val_accuracy: 0.8199
# Epoch 100/100
# 108/108 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.8953
# Epoch 00100: val_loss did not improve from 0.60700
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 108/108 [==============================] - 18s 168ms/step - loss: 0.2881 - accuracy: 0.8953 - val_loss: 0.6998 - val_accuracy: 0.8199
#
#  This Model took 1801.85 seconds (30.0 minutes) to train for 100 epochs

# %% [markdown]
# ### Model Evaluation

# %%
(eval_loss, eval_accuracy) = model.evaluate(  
     X_test, y_test, batch_size=batch_size, verbose=2)
 
print("Accuracy: {:.2f}%".format(eval_accuracy * 100))  
print("Loss: {}".format(eval_loss))
# Out:
# 14/14 - 0s - loss: 0.6531 - accuracy: 0.8199
# Accuracy: 81.99%
# Loss: 0.6531221866607666

# %% [markdown]
# ### Acuuracy and Loss graphs

# %%
# Let's visualize the train/validation loss and accuracy wrt epochs

import matplotlib.pyplot as plt 
def plot(history):
    plt.figure(1)
    #plt.figure(figsize=(10,10)) 
 
     # summarize history for accuracy  
 
    plt.subplot(211)  
    plt.plot(history.history['accuracy'])  
    plt.plot(history.history['val_accuracy'])  
    plt.title('accuracy vs val_accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='lower right')  
 
     # summarize history for loss  
 
    plt.subplot(212)  
    plt.plot(history.history['loss'])  
    plt.plot(history.history['val_loss'])  
    plt.title('loss vs val_loss')  
    plt.ylabel('loss')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.tight_layout()
    plt.show()
 
# Finaly, let's call the plot function with the 'result' parameter 
 
plot(history)

# %% [markdown]
# #### **Few take aways**
# > * From the Training and Validation Accuracy graph above, our model does not seem to be overfitted, which is great!
# * Also, Our Training and Validation Loss graph above also indicates a good learning rate.

# %% [markdown]
# ### Prediction
# > Finally, let us test our model against more random samples from the test data !

# %%
# Let's visualize some random test prediction.
def visualize_pred(y_pred):
# plot a random sample of test images, their predicted labels, and ground truth
    fig = plt.figure(figsize=(16, 9))
    for i, idx in enumerate(np.random.choice(X_test.shape[0], size=16, replace=False)):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(X_test[idx]))
        pred_idx = np.argmax(y_pred[idx])
        true_idx = np.argmax(y_test[idx])
        ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                     color=("green" if pred_idx == true_idx else "red"))

visualize_pred(model.predict(X_test))

# %% [markdown]
# ### Confusion matrix
# I will plotting confusion matrix according to test datas. **0,1,2,3,4** values in this matrix means **daisies, dandelions, roses, sunflowers, tulips** respectively

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Greens",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

# %% [markdown]
# ### **Few Take aways:**
# - The most difficult to detect the type of flower is **rose**.
# - The easiest to detect the type of flower is **daisy**.
# - Most false prediction between **rose** and **tuilps**.

# %% [markdown]
# ### Loading the model
# > Here we are gonna load our best model trained befor, then make some predictions with it !

# %%
my_model=keras.models.load_model('/gdrive/My Drive/PId_Best.h5')

# %%
# Let's visualize some random test prediction.
def visualize_pred(y_pred):
# plot a random sample of test images, their predicted labels, and ground truth
    fig = plt.figure(figsize=(16, 9))
    for i, idx in enumerate(np.random.choice(X_test.shape[0], size=16, replace=False)):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(X_test[idx]))
        pred_idx = np.argmax(y_pred[idx])
        true_idx = np.argmax(y_test[idx])
        ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                     color=("green" if pred_idx == true_idx else "red"))

visualize_pred(my_model.predict(X_test))

# %% [markdown]
# ## **Conclusion**
# The classification precision achieved is great! Considering the quality of data which have been impacted by some issues including :
# - Images with noisy backgrounds;
# - Multiple plant species appearing in the same image;
# - The plant transforms morphologically during its growth... etc.
#
# >This project can be considered quite successful. Of course, there is still much room for improvement. firstly, we can apply the  **Transfer Learning** principe with advanced and popular architectures as VGG16 or ResNet-50 and train it from fine-tuned from pre-trained weights on the popular **ImageNet** dataset.

# %% [markdown]
# **Author : ZEKAOUI Nour Eddine**
#
# *   My [LinkedIn](https://www.linkedin.com/in/nour-eddine-zekaoui-ba43b1177/)
# *   My [GitHub](https://github.com/zekaouinoureddine)
